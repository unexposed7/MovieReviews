# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Dropbox\\Machine_Learning\\Python\\Section 6'

# %%
movies = pd.read_csv('Movie-Ratings.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(movies)
# Out:
# 559

# %%
len(movies.columns)
# Out:
# 6

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns.get_indexer
# Out:
# <bound method Index.get_indexer of Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')>

# %%
movies.columns.all
# Out:
# <bound method Index._add_logical_methods.<locals>._make_logical_function.<locals>.logical_func of Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')>

# %%
movies.columns = ['Film', 'Genre', 'RottenTomatoes', 'Audience', 'Budget', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoes  Audience  Budget  Year
# 0  (500) Days of Summer      Comedy              87        81       8  2009
# 1            10,000 B.C.  Adventure               9        44     105  2008
# 2             12 Rounds      Action              30        52      20  2009
# 3              127 Hours  Adventure              93        84      18  2010
# 4              17 Again      Comedy              55        70      20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# RottenTomatoes    559 non-null int64
# Audience          559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        RottenTomatoes    Audience      Budget         Year
# count      559.000000  559.000000  559.000000   559.000000
# mean        47.309481   58.744186   50.236136  2009.152057
# std         26.413091   16.826887   48.731817     1.362632
# min          0.000000    0.000000    0.000000  2007.000000
# 25%         25.000000   47.000000   20.000000  2008.000000
# 50%         46.000000   58.000000   35.000000  2009.000000
# 75%         70.000000   72.000000   65.000000  2010.000000
# max         97.000000   96.000000  300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoes  Audience  Budget  Year
# 0  (500) Days of Summer      Comedy              87        81       8  2009
# 1            10,000 B.C.  Adventure               9        44     105  2008
# 2             12 Rounds      Action              30        52      20  2009
# 3              127 Hours  Adventure              93        84      18  2010
# 4              17 Again      Comedy              55        70      20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# RottenTomatoes    559 non-null int64
# Audience          559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# RottenTomatoes    559 non-null int64
# Audience          559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movies.describe() # Year is no longer here
# Out:
#        RottenTomatoes    Audience      Budget
# count      559.000000  559.000000  559.000000
# mean        47.309481   58.744186   50.236136
# std         26.413091   16.826887   48.731817
# min          0.000000    0.000000    0.000000
# 25%         25.000000   47.000000   20.000000
# 50%         46.000000   58.000000   35.000000
# 75%         70.000000   72.000000   65.000000
# max         97.000000   96.000000  300.000000

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoes  Audience  Budget  Year
# 0  (500) Days of Summer      Comedy              87        81       8  2009
# 1            10,000 B.C.  Adventure               9        44     105  2008
# 2             12 Rounds      Action              30        52      20  2009
# 3              127 Hours  Adventure              93        84      18  2010
# 4              17 Again      Comedy              55        70      20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# RottenTomatoes    559 non-null int64
# Audience          559 non-null int64
# Budget            559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.codes
# Out:
# 0      2
# 1      1
# 2      0
# 3      1
# 4      2
#       ..
# 554    2
# 555    2
# 556    6
# 557    0
# 558    2
# Length: 559, dtype: int8

# %%
movies.Genre.cat.ordered
# Out:
# False

# %%
#movies.Genre.cat.ordered = True

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
##### Joint Plot

# %%
j = sns.jointplot(data=movies, x='RottenTomatoes', y='Audience',size=8)

# %%
j = sns.jointplot(data=movies, x='RottenTomatoes', y='Audience', kind='kde' , size=8)

# %%
j = sns.jointplot(data=movies, x='RottenTomatoes', y='Audience', kind='reg' , size=8)

# %%
j = sns.jointplot(data=movies, x='RottenTomatoes', y='Audience', kind='resid' , size=8)

# %%
j = sns.jointplot(data=movies, x='RottenTomatoes', y='Audience', kind='hex' , size=8)

# %%
# Chart 1 -

# %% [markdown]
# ---

# %%
# Histograms

# %%
m1 = sns.distplot(movies.Audience, bins=20)

# %%
m2 = sns.distplot(movies.RottenTomatoes, bins=20)

# %%
sns.set_style('white')
n1 = plt.hist(movies.Audience, bins=20)

# %%
sns.set_style('whitegrid')
n2 = plt.hist(movies.RottenTomatoes, bins=20)

# %%
sns.set_style('ticks')
n2 = plt.hist(movies.RottenTomatoes, bins=20)

# %%
sns.set_style('white')
n2 = plt.hist(movies.RottenTomatoes, bins=20)

# %%
sns.set_style('darkgrid')
h1 = sns.distplot(movies.Budget)

# %% [markdown]
# ---

# %%
# Stacked Histograms

# %%
h2 = plt.hist(movies.Budget)

# %%
plt.hist(movies.Budget)
plt.show()

# %%
F1 = movies[movies.RottenTomatoes > 20]

# %%
F1
# Out:
#                                    Film      Genre  RottenTomatoes  Audience  \
# 0                 (500) Days of Summer      Comedy              87        81
# 2                            12 Rounds      Action              30        52
# 3                             127 Hours  Adventure              93        84
# 4                             17 Again      Comedy              55        70
# 5                                  2012     Action              39        63
# 6                            27 Dresses     Comedy              40        71
# 7                      30 Days of Night     Horror              50        57
# 8                    30 Minutes or Less     Comedy              43        48
# 9                                 50/50     Comedy              93        93
# 11                   A Dangerous Method      Drama              79        89
# 13                       A Serious Man       Drama              89        64
# ...

# %%
F1.sort_values(by='RottenTomatoes', ascending=False)
# Out:
#                                     Film      Genre  RottenTomatoes  Audience  \
# 387                           The Artist      Drama              97        91
# 431                     The Hurt Locker       Drama              97        83
# 455                          The Muppets     Comedy              97        87
# 506                            True Grit  Adventure              96        86
# 249                            Moneyball      Drama              95        89
# 275               No Country for Old Men      Drama              95        84
# 196                             Iron Man     Action              94        91
# 362                           Star Trek      Action              94        91
# 440               The Kids Are All Right     Comedy              94        72
# 545                        Winter's Bone      Drama              94        73
# 26                          An Education      Drama              94        78
# ...

# %%
movies.RottenTomatoes.max()
# Out:
# 97

# %%
# and because this is a new dataframe, we can apply .. 
movies[movies.Genre == 'Drama'].Budget
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: Budget, dtype: int64

# %%
h3 = plt.hist(movies[movies.Genre == 'Drama'].Budget)

# %%
h3 = plt.hist(movies[movies.Genre == 'Action'].Budget)

# %%
plt.hist(movies[movies.Genre == 'Comedy'].Budget, bins=15)
plt.hist(movies[movies.Genre == 'Action'].Budget, bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].Budget, bins=15)
plt.hist(movies[movies.Genre == 'Adventure'].Budget)
plt.show()

# %%
movies.Genre.describe()
# Out:
# count        559
# unique         7
# top       Comedy
# freq         172
# Name: Genre, dtype: object

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
lst1 = [movies[movies.Genre == 'Comedy'].Budget,
        movies[movies.Genre == 'Action'].Budget,
        movies[movies.Genre == 'Thriller'].Budget,
       movies[movies.Genre == 'Advanture'].Budget,
       movies[movies.Genre == 'Drama'].Budget,
       movies[movies.Genre == 'Horror'].Budget,
       movies[movies.Genre == 'Romance'].Budget]
plt.hist(lst1)  
plt.show()

# %%
plt.hist(lst1, bins=15, stacked=True, label=movies.Genre)  
plt.show()

# %%
# But instead of doing the monkey job ..

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
lst2 = list()  # or  lst2 = []
for gen in movies.Genre.cat.categories:
    lst2.append(movies[movies.Genre == gen].Budget)

# %%
h3 = plt.hist(lst2, bins=30, stacked=True)

# %%
lst1 = [movies[movies.Genre == 'Action'].Budget,
        movies[movies.Genre == 'Adventure'].Budget,
        movies[movies.Genre == 'Comedy'].Budget,
       movies[movies.Genre == 'Drama'].Budget,
       movies[movies.Genre == 'Horror'].Budget,
       movies[movies.Genre == 'Romance'].Budget,
       movies[movies.Genre == 'Thriller'].Budget]
plt.hist(lst1, bins=15, stacked=True)  
plt.show()
# just to check if they are the same, in the same order

# %%
h3 = plt.hist(lst2, bins=30, stacked=True, rwidth=1)

# %%
mylabel = list()
lst2 = list()  # or  lst2 = []
for gen in movies.Genre.cat.categories:
    lst2.append(movies[movies.Genre == gen].Budget)
    mylabel.append(gen)

# %%
h4 = plt.hist(lst2, bins=30, stacked=True, rwidth=1, label=mylabel)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 50

# %%
# KDE PLOT

# %%
movies.head()
# Out:
#                     Film      Genre  RottenTomatoes  Audience  Budget  Year
# 0  (500) Days of Summer      Comedy              87        81       8  2009
# 1            10,000 B.C.  Adventure               9        44     105  2008
# 2             12 Rounds      Action              30        52      20  2009
# 3              127 Hours  Adventure              93        84      18  2010
# 4              17 Again      Comedy              55        70      20  2009

# %%
vis1 = sns.lmplot(data=movies, x = 'RottenTomatoes', y ='Audience',
                 fit_reg=False, hue='Genre', size=8, aspect=1)

# %%
k1 = sns.kdeplot(movies.RottenTomatoes, movies.Audience, shade=True,
                shade_lowest=False, cmap='Reds')
k1b= sns.kdeplot(movies.RottenTomatoes, movies.Audience,
                 cmap='Reds')

# %%
# Working with subplots()

# %%
k2 = sns.kdeplot(movies.Budget, movies.Audience)

# %%
sns.set_style("dark")

# %%
#sns.set_style("dark")
k1 = sns.kdeplot(movies.Budget, movies.Audience)

# %%
k2 = sns.kdeplot(movies.Budget, movies.RottenTomatoes)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#ax1.plot(x, y)
#ax1.set_title('Sharing Y axis')
#ax2.scatter(x, y)

# %%
f, axes = plt.subplots(1, 2, figsize=(20,9))
k1 = sns.kdeplot(movies.Budget, movies.Audience, ax=axes[0])
k2 = sns.kdeplot(movies.Budget, movies.RottenTomatoes, ax=axes[1])

# %%
f, axes = plt.subplots(2, 2, figsize=(20,9))
k1 = sns.kdeplot(movies.Budget, movies.Audience, ax=axes[0,0])
k2 = sns.kdeplot(movies.Budget, movies.RottenTomatoes, ax=axes[1,1])

# %%
f, axes = plt.subplots(1, 2, figsize=(20,9), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.Budget, movies.Audience, ax=axes[0])
k2 = sns.kdeplot(movies.Budget, movies.RottenTomatoes, ax=axes[1])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %% [markdown]
# ---

# %%
# Violin Plots vs Boxplots

# %%
#w = sns.boxplot(data=movies, x='Genre', y='RottenTomatoes')
w = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y='RottenTomatoes')

# %%
#z = sns.violinplot(data=movies, x='Genre', y='RottenTomatoes')
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='RottenTomatoes')

# %% [markdown]
# ---

# %% [markdown]
# ## Facet Grid - lecture 53

# %%
plt.scatter(movies.RottenTomatoes, movies.Audience)

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='RottenTomatoes')
g = g.map(plt.scatter, 'RottenTomatoes', 'Audience')

# %%
# You can populate with any kind of Chart(s), for ex histograms

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist, 'Budget')

# %%
# back to the scatterplots

# %%
#kws

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'Budget', 'Audience', **kws)

# %%
kws
# Out:
# {'edgecolor': 'black', 'linewidth': 0.5, 's': 50}

# %% [markdown]
# ---

# %% [markdown]
# # Coordinates and Diagonals - Lacture 54

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'Budget', 'Audience', **kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c='black', ls="--")
g.add_legend()

# %%
# <<< CHART 5

# %% [markdown]
# ---

# %%
# Building Dashboards

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))
k1 = sns.kdeplot(movies.Budget, movies.RottenTomatoes, ax=axes[0,0])
k2 = sns.kdeplot(movies.Budget, movies.Audience,  ax=axes[1,0])

z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='RottenTomatoes', ax=axes[0,1])

k3 = sns.kdeplot(movies.RottenTomatoes, movies.Audience, shade=True, shade_lowest=False, cmap='Reds', ax=axes[1,1])
k3b= sns.kdeplot(movies.RottenTomatoes, movies.Audience, cmap='Reds', ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize=(15,15))

k1 = sns.kdeplot(movies.Budget, movies.RottenTomatoes, ax=axes[0,0])
k2 = sns.kdeplot(movies.Budget, movies.Audience,  ax=axes[1,0])

z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='RottenTomatoes', ax=axes[1,1])

axes[0,1].hist(movies.RottenTomatoes, bins=20)

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Lecture 56 - Styling tips
